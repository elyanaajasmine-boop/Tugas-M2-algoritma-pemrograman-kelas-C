# %% [markdown]
# <a href="https://colab.research.google.com/github/elyanaajasmine-boop/Tugas-M2-algoritma-pemrograman-kelas-C/blob/main/Salinan_dari_Tugas_M2_elyana_jasmine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#no.1
total_barang=1250
kapasitas_kardus=45

kardus_penuh=total_barang//kapasitas_kardus
sisa_barang=total_barang%kapasitas_kardus
print(f"jumlah kardus penuh: {kardus_penuh}")
print(f"sisa barang: {sisa_barang}")
# Out:
# jumlah kardus penuh: 27
# sisa barang: 35

# %%
#no.2
skor_produk=85
skor_layanan=70
hasil_penjumlahan=((skor_produk*0.6)+(skor_layanan*0.4))
print (hasil_penjumlahan)
# Out:
# 79.0

# %%
#no.3
biayaPesan=50000
kebutuhanTahunan=1000
biayaSimpan=400
EOQ=int((2*biayaPesan*kebutuhanTahunan)/biayaSimpan**0.5)
print(EOQ)
# Out:
# 5000000

# %%
#no.4
kata1="statistika"
kata2="bisnis"
kata3="ITS"
print(kata1,kata2,kata3)
# Out:
# statistika bisnis its

# %%
#no.5
departemen="Statistika Bisnis"
s=departemen
print (s[0])
print (s[-1])
# Out:
# S
# s

# %%
#no.6
matkul="analisis data eksploratif"
s=matkul
print (s[9:13])
# Out:
# data

# %%
#no.7
nama_matkul="aLgoRitma pEmroGramAn"
print(nama_matkul.title())
# Out:
# Algoritma Pemrograman

# %%
#no.8
teks="mahasiswa DSB kelas 1C sangat senang belajar ALPROG"
print(len(teks))
print(teks.count("a"))
# Out:
# 51
# 9

# %%
#no.9
panjang_maksimal=100
lebar_kolom=4
jumlah_kolom= panjang_maksimal//lebar_kolom
garis_pemisah="="*jumlah_kolom
print("Nomor 9:",garis_pemisah)
# Out:
# Nomor 9: =========================

# %%
#no.10
anggaran=50000
pengeluaran=35000
pesan="sisa saldo anda adalah Rp"
print(pesan+str(anggaran-pengeluaran))
# Out:
# sisa saldo anda adalah Rp15000
