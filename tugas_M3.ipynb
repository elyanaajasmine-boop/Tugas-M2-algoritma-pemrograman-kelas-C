# %% [markdown]
# <a href="https://colab.research.google.com/github/elyanaajasmine-boop/Tugas-M2-algoritma-pemrograman-kelas-C/blob/main/tugas_M3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# no. 3
hari=input("hari")
bulan=input("bulan")
tahun=input("tahun")
print(hari,  bulan, tahun, sep="-")
# Out:
# hari17
# bulanjuli
# tahun2026
# 17-juli-2026

# %%
#no. 1
nama=input("nama panggilan")
alamat=input("alamat")
usia=input("usia")
print(nama, alamat, usia)
# Out:
# nama panggilanelyana
# alamatpucang manyar
# usia17
# elyana pucang manyar 17

# %%
Modal_Awal = float(input("masukkan Modal Awal\t: "))
Target_Keuntungan = Modal_Awal*0.20
print(f"Modal Awal\t\t:Rp{Target_Keuntungan:,.2f}")
print(f"Target Keuntungan\t:Rp{Target_Keuntungan:,.2f}")
# Out:
# masukkan Modal Awal	: 800
# Modal Awal		:Rp160.00
# Target Keuntungan	:Rp160.00

# %%
# no.4
print("ID\t\t Produk\t\t Harga\n")
print ("-")
# Out:
# ID		 Produk		 Harga
#
# -

# %%
# no. 5
barang = "kalkulator scientific"
harga = 245000.5
print(f"Harga {barang} adalah Rp{harga:,.2f}")
# Out:
# Harga kalkulator scientific adalah Rp245,000.50

# %%
nama=input("Nama Lengkap: ")
usia=input("Usia: ")
kontak=input("kontak: ")
alamat=input("Alamat: ")

kampus=input("kampus: ")
fakultas=input("fakultas: ")
Departemen=input("Departemen: ")
NRP=input("NRP: ")
angkatan=input("Angkatan: ")
SKS=input("SKS: ")
Matkul=input("Matkul: ")

TargetKarier = input("Target Karier?")
UsiaKontak=f"{usia} Tahun | {kontak}"
FakDept=F"{fakultas} / {Departemen}"
NrpAngkatan=f"{NRP} / {angkatan}"
SksMatkul=f"{SKS} / {Matkul}"

print()
print("=" * 70)
print(f"| {'DASBOR PROFIL MAHASISWA & RENCANA KARIER':^66} |")
print("=" * 70)
print(f"| {'INFORMASI PERSONAL':<66} |")
print("-" * 70)
print(f"| {'Nama Lengkap':<15} : {nama:<48} |")
print(f"| {'Usia & Kontak':<15} : {UsiaKontak:<48} |")
print(f"| {'Alamat Asal':<15} : {alamat:<48} |")
print("-" * 70)

print(f"| {'INFORMASI AKADEMIK':<66} |")
print("-" * 70)
print(f"| {'Kampus':<15} : {kampus:<48} |")
print(f"| {'Fakultas / Dept':<15} : {FakDept:<48} |")
print(f"| {'NRP / Angkatan':<15} : {NrpAngkatan:<48} |")
print(f"| {'SKS & Matkul':<15} : {SksMatkul:<48} |")
print("=" * 70)

print(f"| {'TARGET KARIER (DREAM JOB)':^66} |")
print(f"| {TargetKarier:^66} |")
print("=" * 70)
# Out:
# Nama Lengkap: Elyana Jasmine Khalila
# Usia: 17 Tahun
# kontak: 08977342214
# Alamat: Surabaya
# kampus: Institut Teknologi Sepuluh Nopember
# fakultas: Vokasi
# Departemen: Statistika Bisnis
# NRP: 2043261128
# Angkatan: 2026
# SKS: 36 SKS
# Matkul: Algoritma dan Pemrograman
# Target Karier?ORANG SUKSES DUNIA DAN AKHIRAT
#
# ...
# |              DASBOR PROFIL MAHASISWA & RENCANA KARIER              |
# ...
# | INFORMASI PERSONAL                                                 |
# ----------------------------------------------------------------------
# | Nama Lengkap    : Elyana Jasmine Khalila                           |
# | Usia & Kontak   : 17 Tahun Tahun | 08977342214                     |
# | Alamat Asal     : Surabaya                                         |
# ----------------------------------------------------------------------
# | INFORMASI AKADEMIK                                                 |
# ----------------------------------------------------------------------
# ...
